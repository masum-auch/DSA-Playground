# %% [markdown]
# <a href="https://colab.research.google.com/github/masum-auch/DSA-Playground/blob/main/01_Basics/02_leniar_tc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learn with time comlplexity on linear

# %%
L= [1, 2, 3, 4, 5]

# %%
sum = 0
for i in L:
  sum = sum+i
print(sum)

product= 1
for i in L:
  product= product*i
print(product)
# Out:
# 15
# 120

# %%
L2= [1, 2, 3, 4, 5]

for i in L2:
  for j in L2:
    print('({}, {})'.format(i,j))
# Out:
# (1, 1)
# (1, 2)
# (1, 3)
# (1, 4)
# (1, 5)
# (2, 1)
# (2, 2)
# (2, 3)
# (2, 4)
# (2, 5)
# (3, 1)
# (3, 2)
# (3, 3)
# (3, 4)
# (3, 5)
# (4, 1)
# (4, 2)
# (4, 3)
# (4, 4)
# (4, 5)
# (5, 1)
# (5, 2)
# (5, 3)
# (5, 4)
# (5, 5)

# %%
def intToStr(i):

  digits= '0123456789'
  if i == 0:
    return '0'
  result= ''
  while i > 0:
    result= digits[i%10] + result
    i = i//10

  return result

print(intToStr(123))
# Out:
# 123
